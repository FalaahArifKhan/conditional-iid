# %%
! pip install virny
# Out:
# zsh:1: /usr/local/bin/pip: bad interpreter: /System/Library/Frameworks/Python.framework/Versions/2.7/Resources/Python.app/Contents/MacOS/Python: no such file or directory
# Collecting virny
#   Downloading virny-0.1.1-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 kB 1.6 MB/s eta 0:00:00
# Collecting sklearn-utils
#   Downloading sklearn_utils-0.0.15.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Collecting xgboost~=1.7.2
#   Downloading xgboost-1.7.5-py3-none-macosx_10_15_x86_64.macosx_11_0_x86_64.macosx_12_0_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 13.4 MB/s eta 0:00:0000:0100:01
# Collecting wheel~=0.38.4
#   Downloading wheel-0.38.4-py3-none-any.whl (36 kB)
# Requirement already satisfied: altair~=4.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from virny) (4.2.0)
# Requirement already satisfied: munch~=2.5.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from virny) (2.5.0)
# Collecting twine~=4.0.2
#   Downloading twine-4.0.2-py3-none-any.whl (36 kB)
# Collecting seaborn~=0.12.1
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 8.2 MB/s eta 0:00:00
# Collecting pandas~=1.5.2
#   Downloading pandas-1.5.3-cp39-cp39-macosx_10_9_x86_64.whl (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 21.4 MB/s eta 0:00:0000:0100:01
# Collecting tqdm~=4.64.1
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: datapane~=0.15.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from virny) (0.15.5)
# Collecting scikit-learn~=1.2.0
#   Downloading scikit_learn-1.2.2-cp39-cp39-macosx_10_9_x86_64.whl (9.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 23.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: folktables~=0.0.11 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from virny) (0.0.11)
# Requirement already satisfied: PyYAML~=6.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from virny) (6.0)
# Collecting matplotlib~=3.6.2
#   Downloading matplotlib-3.6.3-cp39-cp39-macosx_10_12_x86_64.whl (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 23.6 MB/s eta 0:00:0000:0100:01
# Collecting numpy~=1.23.5
#   Downloading numpy-1.23.5-cp39-cp39-macosx_10_9_x86_64.whl (18.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 21.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: jsonschema>=3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from altair~=4.2.0->virny) (3.2.0)
# Requirement already satisfied: entrypoints in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from altair~=4.2.0->virny) (0.3)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from altair~=4.2.0->virny) (3.0.1)
# Requirement already satisfied: toolz in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from altair~=4.2.0->virny) (0.11.2)
# Requirement already satisfied: importlib_resources<6.0.0,>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (5.10.2)
# Requirement already satisfied: datacommons-pandas<0.0.4,>=0.0.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (0.0.3)
# Requirement already satisfied: vega-datasets<1.0.0,>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (0.9.0)
# Requirement already satisfied: nbconvert<7.0.0,>=6.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (6.1.0)
# Requirement already satisfied: micawber>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (0.5.4)
# Requirement already satisfied: dulwich<0.21.0,>=0.20.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (0.20.50)
# Requirement already satisfied: datacommons<2.0.0,>=1.4.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (1.4.3)
# Requirement already satisfied: requests-toolbelt<0.10.0,>=0.9.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (0.9.1)
# Requirement already satisfied: lxml<5.0.0,>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (4.8.0)
# Requirement already satisfied: posthog<3.0.0,>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (2.2.0)
# Requirement already satisfied: chardet<6.0.0,>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (5.1.0)
# Requirement already satisfied: packaging<22.0.0,>=20.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (21.3)
# Requirement already satisfied: requests<3.0.0,>=2.19.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (2.26.0)
# Requirement already satisfied: click<9.0.0,>=7.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (8.0.3)
# Requirement already satisfied: stringcase<2.0.0,>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (1.2.0)
# Requirement already satisfied: pydantic<2.0.0,>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (1.8.2)
# Requirement already satisfied: pyarrow<11.0.0,>=6.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (10.0.1)
# Requirement already satisfied: glom<23.0.0,>=20.11.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (22.1.0)
# Requirement already satisfied: boltons<22.0.0,>=20.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (21.0.0)
# Requirement already satisfied: ipynbname<2022.0.0,>=2021.3.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (2021.3.2)
# Requirement already satisfied: furl<3.0.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (2.1.3)
# Requirement already satisfied: tabulate<0.9.0,>=0.8.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (0.8.10)
# Requirement already satisfied: validators<0.21.0,>=0.18.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (0.20.0)
# Requirement already satisfied: colorlog<7.0.0,>=4.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (6.7.0)
# Requirement already satisfied: click-spinner<0.2.0,>=0.1.8 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (0.1.10)
# Requirement already satisfied: dominate<3.0.0,>=2.4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (2.7.0)
# Requirement already satisfied: dacite<2.0.0,>=1.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datapane~=0.15.5->virny) (1.8.0)
# Requirement already satisfied: sklearn in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from folktables~=0.0.11->virny) (0.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib~=3.6.2->virny) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib~=3.6.2->virny) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib~=3.6.2->virny) (2.4.7)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.39.3-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 15.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib~=3.6.2->virny) (8.3.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib~=3.6.2->virny) (1.3.2)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp39-cp39-macosx_10_9_x86_64.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from munch~=2.5.0->virny) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas~=1.5.2->virny) (2021.1)
# Requirement already satisfied: scipy>=1.3.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-learn~=1.2.0->virny) (1.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-learn~=1.2.0->virny) (2.2.0)
# Collecting joblib>=1.1.1
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 9.1 MB/s eta 0:00:00
# Collecting pkginfo>=1.8.1
#   Downloading pkginfo-1.9.6-py3-none-any.whl (30 kB)
# Collecting rfc3986>=1.4.0
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Collecting readme-renderer>=35.0
#   Downloading readme_renderer-37.3-py3-none-any.whl (14 kB)
# Collecting importlib-metadata>=3.6
#   Downloading importlib_metadata-6.3.0-py3-none-any.whl (22 kB)
# Collecting rich>=12.0.0
#   Downloading rich-13.3.4-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.7/238.7 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from twine~=4.0.2->virny) (1.26.6)
# Collecting keyring>=15.1
#   Downloading keyring-23.13.1-py3-none-any.whl (37 kB)
# Collecting pyfunctional
#   Downloading PyFunctional-1.4.3-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from sklearn-utils->virny) (0.13.2)
# Requirement already satisfied: orderedmultidict>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from furl<3.0.0,>=2.0.0->datapane~=0.15.5->virny) (1.0.1)
# Requirement already satisfied: face>=20.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from glom<23.0.0,>=20.11.0->datapane~=0.15.5->virny) (22.0.0)
# Requirement already satisfied: attrs in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from glom<23.0.0,>=20.11.0->datapane~=0.15.5->virny) (21.2.0)
# Requirement already satisfied: zipp>=0.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from importlib-metadata>=3.6->twine~=4.0.2->virny) (3.12.0)
# Requirement already satisfied: ipykernel in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipynbname<2022.0.0,>=2021.3.2->datapane~=0.15.5->virny) (6.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jinja2->altair~=4.2.0->virny) (2.0.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jsonschema>=3.0->altair~=4.2.0->virny) (0.18.0)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jsonschema>=3.0->altair~=4.2.0->virny) (62.1.0)
# Collecting jaraco.classes
#   Downloading jaraco.classes-3.2.3-py3-none-any.whl (6.0 kB)
# Requirement already satisfied: defusedxml in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert<7.0.0,>=6.1.0->datapane~=0.15.5->virny) (0.7.1)
# Requirement already satisfied: testpath in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert<7.0.0,>=6.1.0->datapane~=0.15.5->virny) (0.5.0)
# Requirement already satisfied: bleach in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert<7.0.0,>=6.1.0->datapane~=0.15.5->virny) (4.1.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert<7.0.0,>=6.1.0->datapane~=0.15.5->virny) (0.5.4)
# Requirement already satisfied: pygments>=2.4.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert<7.0.0,>=6.1.0->datapane~=0.15.5->virny) (2.10.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert<7.0.0,>=6.1.0->datapane~=0.15.5->virny) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert<7.0.0,>=6.1.0->datapane~=0.15.5->virny) (1.4.3)
# Requirement already satisfied: nbformat>=4.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert<7.0.0,>=6.1.0->datapane~=0.15.5->virny) (5.1.3)
# Requirement already satisfied: jupyterlab-pygments in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert<7.0.0,>=6.1.0->datapane~=0.15.5->virny) (0.1.2)
# Requirement already satisfied: traitlets>=5.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert<7.0.0,>=6.1.0->datapane~=0.15.5->virny) (5.1.0)
# Requirement already satisfied: jupyter-core in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert<7.0.0,>=6.1.0->datapane~=0.15.5->virny) (4.7.1)
# Requirement already satisfied: monotonic>=1.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from posthog<3.0.0,>=1.4.0->datapane~=0.15.5->virny) (1.6)
# Requirement already satisfied: backoff<2.0.0,>=1.10.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from posthog<3.0.0,>=1.4.0->datapane~=0.15.5->virny) (1.11.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pydantic<2.0.0,>=1.6.0->datapane~=0.15.5->virny) (3.10.0.2)
# Collecting docutils>=0.13.1
#   Downloading docutils-0.19-py3-none-any.whl (570 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.5/570.5 kB 12.9 MB/s eta 0:00:0000:01
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3.0.0,>=2.19.0->datapane~=0.15.5->virny) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3.0.0,>=2.19.0->datapane~=0.15.5->virny) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests<3.0.0,>=2.19.0->datapane~=0.15.5->virny) (2.0.4)
# Collecting markdown-it-py<3.0.0,>=2.2.0
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 3.2 MB/s eta 0:00:00
# Collecting pygments>=2.4.1
#   Downloading Pygments-2.15.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.3 MB/s eta 0:00:00a 0:00:01
# Collecting scipy>=1.3.2
#   Downloading scipy-1.10.1-cp39-cp39-macosx_10_9_x86_64.whl (35.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 17.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: decorator>=3.4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from validators<0.21.0,>=0.18.0->datapane~=0.15.5->virny) (5.1.0)
# Collecting dill>=0.2.5
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: patsy>=0.5.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from statsmodels->sklearn-utils->virny) (0.5.2)
# Requirement already satisfied: webencodings in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from bleach->nbconvert<7.0.0,>=6.1.0->datapane~=0.15.5->virny) (0.5.1)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: jupyter-client>=6.1.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert<7.0.0,>=6.1.0->datapane~=0.15.5->virny) (7.0.2)
# Requirement already satisfied: nest-asyncio in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert<7.0.0,>=6.1.0->datapane~=0.15.5->virny) (1.5.1)
# Requirement already satisfied: ipython-genutils in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbformat>=4.4->nbconvert<7.0.0,>=6.1.0->datapane~=0.15.5->virny) (0.2.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane~=0.15.5->virny) (1.4.3)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane~=0.15.5->virny) (0.1.3)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane~=0.15.5->virny) (6.1)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane~=0.15.5->virny) (7.27.0)
# Requirement already satisfied: appnope in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane~=0.15.5->virny) (0.1.2)
# Collecting more-itertools
#   Downloading more_itertools-9.1.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane~=0.15.5->virny) (3.0.20)
# Requirement already satisfied: backcall in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane~=0.15.5->virny) (0.2.0)
# Requirement already satisfied: pickleshare in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane~=0.15.5->virny) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane~=0.15.5->virny) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane~=0.15.5->virny) (0.18.0)
# Requirement already satisfied: pyzmq>=13 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert<7.0.0,>=6.1.0->datapane~=0.15.5->virny) (22.2.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane~=0.15.5->virny) (0.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pexpect>4.3->ipython<8.0,>=7.23.1->ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane~=0.15.5->virny) (0.7.0)
# Requirement already satisfied: wcwidth in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel->ipynbname<2022.0.0,>=2021.3.2->datapane~=0.15.5->virny) (0.2.5)
# Building wheels for collected packages: sklearn-utils
#   Building wheel for sklearn-utils (setup.py) ... done
#   Created wheel for sklearn-utils: filename=sklearn_utils-0.0.15-py3-none-any.whl size=27890 sha256=0c7ff5b289628b6fe502f7c341822975aa172ce3a2d704ffab9724b10502de8d
#   Stored in directory: /Users/falaaharifkhan/Library/Caches/pip/wheels/ae/aa/20/75c06f64979aca41815d1fbdcc71599330da9b60cc4f8de0b2
# Successfully built sklearn-utils
# Installing collected packages: wheel, tqdm, rfc3986, pygments, pkginfo, numpy, more-itertools, mdurl, joblib, importlib-metadata, fonttools, docutils, dill, scipy, pyfunctional, pandas, markdown-it-py, jaraco.classes, contourpy, xgboost, scikit-learn, rich, readme-renderer, matplotlib, keyring, twine, seaborn, sklearn-utils, virny
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.37.1
#     Uninstalling wheel-0.37.1:
#       Successfully uninstalled wheel-0.37.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.62.3
#     Uninstalling tqdm-4.62.3:
#       Successfully uninstalled tqdm-4.62.3
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.10.0
#     Uninstalling Pygments-2.10.0:
#       Successfully uninstalled Pygments-2.10.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.2
#     Uninstalling numpy-1.21.2:
#       Successfully uninstalled numpy-1.21.2
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.0.1
#     Uninstalling joblib-1.0.1:
#       Successfully uninstalled joblib-1.0.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.1
#     Uninstalling scipy-1.7.1:
#       Successfully uninstalled scipy-1.7.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.2
#     Uninstalling pandas-1.3.2:
#       Successfully uninstalled pandas-1.3.2
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 1.6.1
#     Uninstalling xgboost-1.6.1:
#       Successfully uninstalled xgboost-1.6.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.1.1
#     Uninstalling scikit-learn-1.1.1:
#       Successfully uninstalled scikit-learn-1.1.1
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.4.3
#     Uninstalling matplotlib-3.4.3:
#       Successfully uninstalled matplotlib-3.4.3
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.2
#     Uninstalling seaborn-0.11.2:
#       Successfully uninstalled seaborn-0.11.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datawig 0.2.0 requires mxnet==1.4.0, which is not installed.
# datawig 0.2.0 requires typing==3.6.6, which is not installed.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.23.5 which is incompatible.
# datawig 0.2.0 requires pandas==0.25.3, but you have pandas 1.5.3 which is incompatible.
# datawig 0.2.0 requires scikit-learn[alldeps]==0.22.1, but you have scikit-learn 1.2.2 which is incompatible.
# Successfully installed contourpy-1.0.7 dill-0.3.6 docutils-0.19 fonttools-4.39.3 importlib-metadata-6.3.0 jaraco.classes-3.2.3 joblib-1.2.0 keyring-23.13.1 markdown-it-py-2.2.0 matplotlib-3.6.3 mdurl-0.1.2 more-itertools-9.1.0 numpy-1.23.5 pandas-1.5.3 pkginfo-1.9.6 pyfunctional-1.4.3 pygments-2.15.0 readme-renderer-37.3 rfc3986-2.0.0 rich-13.3.4 scikit-learn-1.2.2 scipy-1.10.1 seaborn-0.12.2 sklearn-utils-0.0.15 tqdm-4.64.1 twine-4.0.2 virny-0.1.1 wheel-0.38.4 xgboost-1.7.5
#
# [notice] A new release of pip available: 22.2.1 -> 23.0.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %%
! pip install tempeh
# Out:
# zsh:1: /usr/local/bin/pip: bad interpreter: /System/Library/Frameworks/Python.framework/Versions/2.7/Resources/Python.app/Contents/MacOS/Python: no such file or directory
# Requirement already satisfied: tempeh in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (0.1.12)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tempeh) (1.2.2)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tempeh) (1.5.3)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tempeh) (2.26.0)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tempeh) (1.23.5)
# Requirement already satisfied: pytest in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tempeh) (7.1.2)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tempeh) (1.10.1)
# Requirement already satisfied: shap in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tempeh) (0.40.0)
# Requirement already satisfied: memory-profiler in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from tempeh) (0.61.0)
# Requirement already satisfied: psutil in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from memory-profiler->tempeh) (5.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas->tempeh) (2021.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas->tempeh) (2.8.2)
# Requirement already satisfied: tomli>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pytest->tempeh) (2.0.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pytest->tempeh) (1.0.0)
# Requirement already satisfied: attrs>=19.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pytest->tempeh) (21.2.0)
# Requirement already satisfied: iniconfig in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pytest->tempeh) (1.1.1)
# Requirement already satisfied: py>=1.8.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pytest->tempeh) (1.11.0)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pytest->tempeh) (21.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->tempeh) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->tempeh) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->tempeh) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->tempeh) (2021.10.8)
# Requirement already satisfied: joblib>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-learn->tempeh) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-learn->tempeh) (2.2.0)
# Requirement already satisfied: slicer==0.0.7 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from shap->tempeh) (0.0.7)
# Requirement already satisfied: numba in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from shap->tempeh) (0.55.1)
# Requirement already satisfied: cloudpickle in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from shap->tempeh) (2.0.0)
# Requirement already satisfied: tqdm>4.25.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from shap->tempeh) (4.64.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from packaging->pytest->tempeh) (2.4.7)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->tempeh) (1.16.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from numba->shap->tempeh) (0.38.0)
# Collecting numpy
#   Downloading numpy-1.21.6-cp39-cp39-macosx_10_9_x86_64.whl (17.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 25.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from numba->shap->tempeh) (62.1.0)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datawig 0.2.0 requires mxnet==1.4.0, which is not installed.
# datawig 0.2.0 requires typing==3.6.6, which is not installed.
# virny 0.1.1 requires numpy~=1.23.5, but you have numpy 1.21.6 which is incompatible.
# datawig 0.2.0 requires pandas==0.25.3, but you have pandas 1.5.3 which is incompatible.
# datawig 0.2.0 requires scikit-learn[alldeps]==0.22.1, but you have scikit-learn 1.2.2 which is incompatible.
# Successfully installed numpy-1.21.6
#
# [notice] A new release of pip available: 22.2.1 -> 23.0.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np
import scipy as sp 
import seaborn as sns
import matplotlib.pyplot as plt

from data_loader import CompasDataset, ACSEmploymentDataset
from utils import predict_ensemble, predict_CIID
from utils import partition_by_group_intersectional, partition_by_group_binary, set_protected_groups
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (5.1.0)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
